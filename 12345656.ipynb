# %% [markdown]
# <a href="https://colab.research.google.com/github/phupha007-1/deadline_survivor/blob/main/12345656.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("a")
# Out:
# a

# %%
print("b")
# Out:
# b

# %%
print("c")
# Out:
# c
